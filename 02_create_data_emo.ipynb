# %%
import pandas as pd

# 1. Cargar el CSV con el riesgo clínico
df = pd.read_csv("Dataframe/data_riesgo_clinico.csv")

# Filtrar y contar pacientes con riesgo > 70
n_mayores_70 = (df["riesgo_clinico"] > 70).sum()

print(f"📊 Pacientes con riesgo clínico > 70: {n_mayores_70}")
# Out:
# 📊 Pacientes con riesgo clínico > 70: 0

# %%
df
# Out:
#       disease_type  primary_site  gender.demographic  \
# 0                1            19                   0
# 1                1            19                   1
# 2                1            19                   1
# 3                1            19                   1
# 4                1            19                   1
# ...            ...           ...                 ...
# 9852            24            16                   0
# 9853            24            45                   1
# 9854            24            45                   1
# 9855            24            45                   1
# 9856            24            45                   0
#
#       age_at_index.demographic  days_to_birth.demographic  \
# 0                         61.0                   -22320.0
# 1                         42.0                   -15360.0
# 2                         42.0                   -15360.0
# 3                         68.0                   -24850.0
# 4                         68.0                   -24850.0
# ...                        ...                        ...
# 9852                      71.0                   -26167.0
# 9853                      53.0                   -19424.0
# 9854                      67.0                   -24487.0
# 9855                      67.0                   -24802.0
# 9856                      52.0                   -19276.0
#
#       year_of_birth.demographic  tissue_or_organ_of_origin.diagnoses  \
# 0                        1946.0                                   57
# 1                        1966.0                                   57
# 2                        1966.0                                   57
# 3                        1939.0                                   57
# 4                        1939.0                                   57
# ...                         ...                                  ...
# 9852                     1942.0                                    2
# 9853                     1955.0                                  114
# 9854                     1935.0                                  114
# 9855                     1946.0                                  114
# 9856                     1957.0                                  114
#
#       age_at_diagnosis.diagnoses  primary_diagnosis.diagnoses  \
# 0                        22320.0                           28
# 1                        15360.0                           28
# 2                        15360.0                           28
# 3                        24850.0                           28
# 4                        24850.0                           28
# ...                          ...                          ...
# 9852                     26167.0                          114
# 9853                     19424.0                          122
# 9854                     24487.0                          122
# 9855                     24802.0                          115
# 9856                     19276.0                          114
#
#       year_of_diagnosis.diagnoses  ...  treatment_type.treatments.diagnoses  \
# 0                          2007.0  ...                                    0
# 1                          2008.0  ...                                    1
# 2                          2008.0  ...                                    1
# 3                          2007.0  ...                                    1
# 4                          2007.0  ...                                    1
# ...                           ...  ...                                  ...
# 9852                       2013.0  ...                                    1
# 9853                       2008.0  ...                                    0
# 9854                       2002.0  ...                                    0
# 9855                       2013.0  ...                                    1
# 9856                       2009.0  ...                                    0
#
#       treatment_or_therapy.treatments.diagnoses  tumor_descriptor.samples  \
# 0                                             0                         3
# 1                                             4                         3
# 2                                             4                         2
# 3                                             4                         3
# 4                                             4                         2
# ...                                         ...                       ...
# 9852                                          2                         3
# 9853                                          0                         3
# 9854                                          2                         3
# 9855                                          0                         3
# 9856                                          8                         3
#
#       sample_type.samples  tissue_type.samples  tipo_cancer_TCGA  \
# 0                       4                    1                11
# 1                       4                    1                11
# 2                       6                    0                11
# 3                       4                    1                11
# 4                       6                    0                11
# ...                   ...                  ...               ...
# 9852                    4                    1                29
# 9853                    4                    1                29
# 9854                    4                    1                29
# 9855                    4                    1                29
# 9856                    4                    1                29
#
#       tipo_cancer_general  censored  duration  riesgo_clinico
# 0                      21         1    2150.0        0.635392
# 1                      21         1     211.0        0.798787
# 2                      21         1     211.0        0.845942
# 3                      21         1    1371.0        0.648260
# 4                      21         1    1371.0        0.686529
# ...                   ...       ...       ...             ...
# 9852                   25         1     714.0        3.395773
# 9853                   25         1    2354.0        0.571912
# 9854                   25         1    4562.0        0.084965
# 9855                   25         1     386.0        3.158677
# 9856                   25         1    1789.0        0.797080
#
# [9857 rows x 23 columns]

# %%
import numpy as np
q_low = np.percentile(df["riesgo_clinico"], 33)
q_high = np.percentile(df["riesgo_clinico"], 52)

# %%
print(q_high)
print(q_low)
# Out:
# 1.553159085714774
# 0.8004815202222924

# %%
import numpy as np

def generar_variables_emocionales(riesgo_clinico, q_low, q_high):
    if riesgo_clinico > q_high:
        responsabilidad = np.random.randint(1, 2)
        neuroticismo = np.random.randint(4, 6)
        extraversion = np.random.randint(1, 2)
        amabilidad = np.random.randint(1, 2)
        apertura = np.random.randint(1, 2)

        ansiedad = np.random.choice([0, 1, 2, 3], p=[0.1, 0.1, 0.4, 0.4])
        depresion = np.random.choice([0, 1, 2, 3], p=[0.1, 0.1, 0.4, 0.4])
        estres = np.random.choice([0, 1, 2, 3], p=[0.1, 0.1, 0.4, 0.4])

        apoyo = np.random.choice(["No", "Sí"], p=[0.8, 0.2])

        alcohol = np.random.choice(["Nunca", "Ocasionalmente", "Frecuentemente"], p=[0.1, 0.4, 0.5])
        fuma_actual = np.random.choice(["No", "Sí, <5 cigarros/día", "Sí, >5 cigarros/día"], p=[0.1, 0.2, 0.7])
        fue_fumador = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue siéndolo"], p=[0.1, 0.3, 0.6])
        alcohol_problema = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue teniendo actualmente"], p=[0.1, 0.3, 0.6])
        drogas_pasado = np.random.choice(["No", "Ocasionalmente", "Frecuentemente"], p=[0.1, 0.4, 0.5])
        drogas_ahora = np.random.choice(["No", "Ocasionalmente", "Habitualmente"], p=[0.2, 0.5, 0.3])
        drogas_problema = np.random.choice(["No", "Sí"], p=[0.2, 0.8])

        ejercicio = np.random.choice(["No", "Sí"], p=[0.8, 0.2])
        alimentacion = np.random.choice(["No", "Sí"], p=[0.8, 0.2])

    elif riesgo_clinico < q_low:
        responsabilidad = np.random.randint(4, 6)
        neuroticismo = np.random.randint(1, 2)
        extraversion = np.random.randint(4, 6)
        amabilidad = np.random.randint(4, 6)
        apertura = np.random.randint(4, 6)

        ansiedad = np.random.choice([0, 1, 2, 3], p=[0.5, 0.3, 0.1, 0.1])
        depresion = np.random.choice([0, 1, 2, 3], p=[0.5, 0.3, 0.1, 0.1])
        estres = np.random.choice([0, 1, 2, 3], p=[0.5, 0.3, 0.1, 0.1])

        apoyo = np.random.choice(["No", "Sí"], p=[0.2, 0.8])  #0 no tiene apoyo, 1 tiene apoyo

        alcohol = np.random.choice(["Nunca", "Ocasionalmente", "Frecuentemente"], p=[0.7, 0.25, 0.05])
        fuma_actual = np.random.choice(["No", "Sí, <5 cigarros/día", "Sí, >5 cigarros/día"], p=[0.8, 0.15, 0.05])
        fue_fumador = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue siéndolo"], p=[0.7, 0.2, 0.1])
        alcohol_problema = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue teniendo actualmente"], p=[0.9, 0.05, 0.05])
        drogas_pasado = np.random.choice(["No", "Ocasionalmente", "Frecuentemente"], p=[0.85, 0.1, 0.05])
        drogas_ahora = np.random.choice(["No", "Ocasionalmente", "Habitualmente"], p=[0.9, 0.08, 0.02])
        drogas_problema = np.random.choice(["No", "Sí"], p=[0.7, 0.3])

        ejercicio = np.random.choice(["No", "Sí"], p=[0.2, 0.8])
        alimentacion = np.random.choice(["No", "Sí"], p=[0.2, 0.8])

    else:
        responsabilidad = np.random.randint(2, 5)
        neuroticismo = np.random.randint(2, 5)
        extraversion = np.random.randint(2, 5)
        amabilidad = np.random.randint(2, 5)
        apertura = np.random.randint(2, 5)

        ansiedad = np.random.choice([0, 1, 2, 3])
        depresion = np.random.choice([0, 1, 2, 3])
        estres = np.random.choice([0, 1, 2, 3])

        apoyo = np.random.choice(["No", "Sí"])

        alcohol = np.random.choice(["Nunca", "Ocasionalmente", "Frecuentemente"])
        fuma_actual = np.random.choice(["No", "Sí, <5 cigarros/día", "Sí, >5 cigarros/día"])
        fue_fumador = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue siéndolo"])
        alcohol_problema = np.random.choice(["No", "Sí, en el pasado", "Sí, sigue teniendo actualmente"])
        drogas_pasado = np.random.choice(["No", "Ocasionalmente", "Frecuentemente"])
        drogas_ahora = np.random.choice(["No", "Ocasionalmente", "Habitualmente"])
        drogas_problema = np.random.choice(["No", "Sí"])

        ejercicio = np.random.choice(["No", "Sí"])
        alimentacion = np.random.choice(["No", "Sí"])

    return {
        "responsabilidad": responsabilidad,
        "neuroticismo": neuroticismo,
        "extraversión": extraversion,
        "amabilidad": amabilidad,
        "apertura": apertura,
        "ansiedad": ansiedad,
        "depresion": depresion,
        "estres": estres,
        "apoyo": apoyo,
        "alcohol": alcohol,
        "fuma_actual": fuma_actual,
        "fue_fumador": fue_fumador,
        "alcohol_problema": alcohol_problema,
        "drogas_pasado": drogas_pasado,
        "drogas_ahora": drogas_ahora,
        "drogas_problema": drogas_problema,
        "ejercicio": ejercicio,
        "alimentacion": alimentacion,
    }

# %%
variables_emocionales = df["riesgo_clinico"].apply(
    lambda r: generar_variables_emocionales(r, q_low, q_high)
)

# Convertir a DataFrame y concatenar
df_emocionales = pd.DataFrame(variables_emocionales.tolist())
df_completo = pd.concat([df, df_emocionales], axis=1)

# %%
df_completo
# Out:
#       disease_type  primary_site  gender.demographic  \
# 0                1            19                   0
# 1                1            19                   1
# 2                1            19                   1
# 3                1            19                   1
# 4                1            19                   1
# ...            ...           ...                 ...
# 9852            24            16                   0
# 9853            24            45                   1
# 9854            24            45                   1
# 9855            24            45                   1
# 9856            24            45                   0
#
#       age_at_index.demographic  days_to_birth.demographic  \
# 0                         61.0                   -22320.0
# 1                         42.0                   -15360.0
# 2                         42.0                   -15360.0
# 3                         68.0                   -24850.0
# 4                         68.0                   -24850.0
# ...                        ...                        ...
# 9852                      71.0                   -26167.0
# 9853                      53.0                   -19424.0
# 9854                      67.0                   -24487.0
# 9855                      67.0                   -24802.0
# 9856                      52.0                   -19276.0
#
#       year_of_birth.demographic  tissue_or_organ_of_origin.diagnoses  \
# 0                        1946.0                                   57
# 1                        1966.0                                   57
# 2                        1966.0                                   57
# 3                        1939.0                                   57
# 4                        1939.0                                   57
# ...                         ...                                  ...
# 9852                     1942.0                                    2
# 9853                     1955.0                                  114
# 9854                     1935.0                                  114
# 9855                     1946.0                                  114
# 9856                     1957.0                                  114
#
#       age_at_diagnosis.diagnoses  primary_diagnosis.diagnoses  \
# 0                        22320.0                           28
# 1                        15360.0                           28
# 2                        15360.0                           28
# 3                        24850.0                           28
# 4                        24850.0                           28
# ...                          ...                          ...
# 9852                     26167.0                          114
# 9853                     19424.0                          122
# 9854                     24487.0                          122
# 9855                     24802.0                          115
# 9856                     19276.0                          114
#
#       year_of_diagnosis.diagnoses  ...  apoyo         alcohol  \
# 0                          2007.0  ...     Sí           Nunca
# 1                          2008.0  ...     Sí  Frecuentemente
# 2                          2008.0  ...     Sí  Ocasionalmente
# 3                          2007.0  ...     No           Nunca
# 4                          2007.0  ...     No  Frecuentemente
# ...                           ...  ...    ...             ...
# 9852                       2013.0  ...     Sí  Frecuentemente
# 9853                       2008.0  ...     No  Ocasionalmente
# 9854                       2002.0  ...     Sí  Ocasionalmente
# 9855                       2013.0  ...     No  Ocasionalmente
# 9856                       2009.0  ...     No           Nunca
#
#               fuma_actual         fue_fumador                alcohol_problema  \
# 0     Sí, <5 cigarros/día                  No                              No
# 1     Sí, <5 cigarros/día                  No                              No
# 2     Sí, >5 cigarros/día    Sí, en el pasado                Sí, en el pasado
# 3                      No                  No                              No
# 4                      No                  No                              No
# ...                   ...                 ...                             ...
# 9852                   No                  No  Sí, sigue teniendo actualmente
# 9853  Sí, >5 cigarros/día    Sí, en el pasado                              No
# 9854                   No                  No                              No
# 9855  Sí, <5 cigarros/día  Sí, sigue siéndolo  Sí, sigue teniendo actualmente
# 9856                   No                  No                              No
#
#        drogas_pasado    drogas_ahora  drogas_problema  ejercicio  alimentacion
# 0                 No              No               No         Sí            Sí
# 1                 No              No               No         Sí            Sí
# 2     Frecuentemente              No               Sí         No            No
# 3                 No  Ocasionalmente               Sí         Sí            No
# 4     Ocasionalmente              No               No         Sí            Sí
# ...              ...             ...              ...        ...           ...
# 9852  Frecuentemente              No               Sí         No            Sí
# 9853              No              No               Sí         Sí            Sí
# 9854              No              No               No         Sí            Sí
# 9855  Frecuentemente  Ocasionalmente               Sí         No            No
# 9856              No              No               No         Sí            Sí
#
# [9857 rows x 41 columns]

# %%
print(df_completo['apoyo'].unique())
# Out:
# ['Sí' 'No']

# %%
df_completo = df_completo.drop(columns=["riesgo_clinico"])

# %%
print(df_completo.columns.tolist())
# Out:
# ['disease_type', 'primary_site', 'gender.demographic', 'age_at_index.demographic', 'days_to_birth.demographic', 'year_of_birth.demographic', 'tissue_or_organ_of_origin.diagnoses', 'age_at_diagnosis.diagnoses', 'primary_diagnosis.diagnoses', 'year_of_diagnosis.diagnoses', 'prior_treatment.diagnoses', 'morphology.diagnoses', 'site_of_resection_or_biopsy.diagnoses', 'treatment_type.treatments.diagnoses', 'treatment_or_therapy.treatments.diagnoses', 'tumor_descriptor.samples', 'sample_type.samples', 'tissue_type.samples', 'tipo_cancer_TCGA', 'tipo_cancer_general', 'censored', 'duration', 'responsabilidad', 'neuroticismo', 'extraversión', 'amabilidad', 'apertura', 'ansiedad', 'depresion', 'estres', 'apoyo', 'alcohol', 'fuma_actual', 'fue_fumador', 'alcohol_problema', 'drogas_pasado', 'drogas_ahora', 'drogas_problema', 'ejercicio', 'alimentacion']

# %%
from sklearn.preprocessing import LabelEncoder
import joblib
import os

# Crear el directorio si no existe
os.makedirs("../Outputs/encoder", exist_ok=True)

# Seleccionar las columnas categóricas
categorical_cols = df_completo.select_dtypes(include=['object', 'category']).columns.tolist()

# Crear el LabelEncoder
le = LabelEncoder()

# Transformar las columnas categóricas y mostrar el mapeo
codificaciones = {}  # Diccionario para almacenar las codificaciones

for col in categorical_cols:
    le.fit(df_completo[col])  # Ajustar el LabelEncoder a la columna
    df_completo[col] = le.transform(df_completo[col])  # Transformar la columna
    joblib.dump(le, f"Outputs/encoder_emo/encoder_emo_{col}.pkl")  # Guardar codificador
    
    # Guardar el mapeo de valores originales y codificados
    codificaciones[col] = dict(zip(le.classes_, le.transform(le.classes_)))

# Imprimir las codificaciones
for col, mapping in codificaciones.items():
    print(f"Codificación para '{col}': {mapping}")
# Out:
# Codificación para 'apoyo': {'No': 0, 'Sí': 1}
# Codificación para 'alcohol': {'Frecuentemente': 0, 'Nunca': 1, 'Ocasionalmente': 2}
# Codificación para 'fuma_actual': {'No': 0, 'Sí, <5 cigarros/día': 1, 'Sí, >5 cigarros/día': 2}
# Codificación para 'fue_fumador': {'No': 0, 'Sí, en el pasado': 1, 'Sí, sigue siéndolo': 2}
# Codificación para 'alcohol_problema': {'No': 0, 'Sí, en el pasado': 1, 'Sí, sigue teniendo actualmente': 2}
# Codificación para 'drogas_pasado': {'Frecuentemente': 0, 'No': 1, 'Ocasionalmente': 2}
# Codificación para 'drogas_ahora': {'Habitualmente': 0, 'No': 1, 'Ocasionalmente': 2}
# Codificación para 'drogas_problema': {'No': 0, 'Sí': 1}
# Codificación para 'ejercicio': {'No': 0, 'Sí': 1}
# Codificación para 'alimentacion': {'No': 0, 'Sí': 1}

# %%
df_completo
# Out:
#       disease_type  primary_site  gender.demographic  \
# 0                1            19                   0
# 1                1            19                   1
# 2                1            19                   1
# 3                1            19                   1
# 4                1            19                   1
# ...            ...           ...                 ...
# 9852            24            16                   0
# 9853            24            45                   1
# 9854            24            45                   1
# 9855            24            45                   1
# 9856            24            45                   0
#
#       age_at_index.demographic  days_to_birth.demographic  \
# 0                         61.0                   -22320.0
# 1                         42.0                   -15360.0
# 2                         42.0                   -15360.0
# 3                         68.0                   -24850.0
# 4                         68.0                   -24850.0
# ...                        ...                        ...
# 9852                      71.0                   -26167.0
# 9853                      53.0                   -19424.0
# 9854                      67.0                   -24487.0
# 9855                      67.0                   -24802.0
# 9856                      52.0                   -19276.0
#
#       year_of_birth.demographic  tissue_or_organ_of_origin.diagnoses  \
# 0                        1946.0                                   57
# 1                        1966.0                                   57
# 2                        1966.0                                   57
# 3                        1939.0                                   57
# 4                        1939.0                                   57
# ...                         ...                                  ...
# 9852                     1942.0                                    2
# 9853                     1955.0                                  114
# 9854                     1935.0                                  114
# 9855                     1946.0                                  114
# 9856                     1957.0                                  114
#
#       age_at_diagnosis.diagnoses  primary_diagnosis.diagnoses  \
# 0                        22320.0                           28
# 1                        15360.0                           28
# 2                        15360.0                           28
# 3                        24850.0                           28
# 4                        24850.0                           28
# ...                          ...                          ...
# 9852                     26167.0                          114
# 9853                     19424.0                          122
# 9854                     24487.0                          122
# 9855                     24802.0                          115
# 9856                     19276.0                          114
#
#       year_of_diagnosis.diagnoses  ...  apoyo  alcohol  fuma_actual  \
# 0                          2007.0  ...      1        1            1
# 1                          2008.0  ...      1        0            1
# 2                          2008.0  ...      1        2            2
# 3                          2007.0  ...      0        1            0
# 4                          2007.0  ...      0        0            0
# ...                           ...  ...    ...      ...          ...
# 9852                       2013.0  ...      1        0            0
# 9853                       2008.0  ...      0        2            2
# 9854                       2002.0  ...      1        2            0
# 9855                       2013.0  ...      0        2            1
# 9856                       2009.0  ...      0        1            0
#
#       fue_fumador  alcohol_problema  drogas_pasado  drogas_ahora  \
# 0               0                 0              1             1
# 1               0                 0              1             1
# 2               1                 1              0             1
# 3               0                 0              1             2
# 4               0                 0              2             1
# ...           ...               ...            ...           ...
# 9852            0                 2              0             1
# 9853            1                 0              1             1
# 9854            0                 0              1             1
# 9855            2                 2              0             2
# 9856            0                 0              1             1
#
#       drogas_problema  ejercicio  alimentacion
# 0                   0          1             1
# 1                   0          1             1
# 2                   1          0             0
# 3                   1          1             0
# 4                   0          1             1
# ...               ...        ...           ...
# 9852                1          0             1
# 9853                1          1             1
# 9854                0          1             1
# 9855                1          0             0
# 9856                0          1             1
#
# [9857 rows x 40 columns]

# %%
df_completo.to_csv("Dataframe/data_emocional.csv", index=False)
print("✅ Archivo guardado sin la columna 'riesgo_clinico'")
# Out:
# ✅ Archivo guardado sin la columna 'riesgo_clinico'
